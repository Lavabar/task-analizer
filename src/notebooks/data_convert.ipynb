# %%
import pandas as pd

# %%
DATA_PATH = "../../data/prepared_data/"

# %%
df = pd.read_csv(DATA_PATH + "stories_data.csv")

# %%
df
# Out:
#      Unnamed: 0                       _id fields.issuetype.name  \
# 0             0  61d5d460f4d395ee2218a9fe                 Story
# 1             1  61d5d541f4d395ee2218e245                 Story
# 2             2  61d5d541f4d395ee2218e24f                 Story
# 3             3  61d5d541f4d395ee2218e255                 Story
# 4             4  61d5d541f4d395ee2218e264                 Story
# ..          ...                       ...                   ...
# 96           96  61d5d541f4d395ee2218e2e6                 Story
# 97           97  61d5d541f4d395ee2218e2e7                 Story
# 98           98  61d5d541f4d395ee2218e2e8                 Story
# 99           99  61d5d541f4d395ee2218e2e9                 Story
# 100         100  61d5d541f4d395ee2218e2ea                 Story
#
#                                     fields.description  \
# 0    @@Complet Regarder Film Exodus: Gods And Kings...
# 1    In user-grid tools we already have tools to id...
# 2    We are not able to send push notification to a...
# 3    Implement a query analyzer such that the follo...
# 4    We have been encountering INSTALLATION issues ...
# ..                                                 ...
# 96   PROBLEM: \n- I request a user's activity feed....
# 97   This is just to pick off any low-hanging fruit...
# 98                                                 NaN
# 99   Doing PUT creates a duplicate edge on /managem...
# 100  - Will need superuser credentials.\n- Will del...
#
#                                         fields.summary
# 0    @@Complet Regarder Film Exodus: Gods And Kings...
# 1     Create a tool to bulk update Unique value table.
# 2    One of Cassandra Column family is deleted , we...
# 3                           Implement a query analyzer
# 4    Usergrid 2.2 Master, Tomcat Startup Error: unc...
# ..                                                 ...
# 96   Cursor lists previous cursor's data (activity ...
# 97                      Fix confusing error message(s)
# 98   REST - Ensure that user creation is blocked if...
# 99   Ensure that PUT or POST does not create duplic...
# 100                         Add DELETE for Admin Users
#
# [101 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '_id', 'fields.issuetype.name', 'fields.description',
#        'fields.summary'],
#       dtype='object')

# %%
df[:][df['fields.description'].str.contains('when').fillna(False)]
# Out:
# /var/folders/04/d3p595hn02q4s9m3rgm6d__40000gn/T/ipykernel_92640/1928467068.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[:][df['fields.description'].str.contains('when').fillna(False)]
#     Unnamed: 0                       _id fields.issuetype.name  \
# 7            7  61d5d541f4d395ee2218e26a                 Story
# 8            8  61d5d541f4d395ee2218e26f                 Story
# 17          17  61d5d541f4d395ee2218e27f                 Story
# 18          18  61d5d541f4d395ee2218e280                 Story
# 20          20  61d5d541f4d395ee2218e284                 Story
# 21          21  61d5d541f4d395ee2218e285                 Story
# 28          28  61d5d541f4d395ee2218e291                 Story
# 32          32  61d5d541f4d395ee2218e296                 Story
# 34          34  61d5d541f4d395ee2218e299                 Story
# 36          36  61d5d541f4d395ee2218e2a0                 Story
# 43          43  61d5d541f4d395ee2218e2a8                 Story
# 44          44  61d5d541f4d395ee2218e2a9                 Story
# 51          51  61d5d541f4d395ee2218e2b1                 Story
# 55          55  61d5d541f4d395ee2218e2b6                 Story
# 61          61  61d5d541f4d395ee2218e2be                 Story
# 76          76  61d5d541f4d395ee2218e2cd                 Story
# 88          88  61d5d541f4d395ee2218e2dc                 Story
#
#                                    fields.description  \
# 7   At the moment, the log message when there is a...
# 8   Investigate and fix: no cursor returned when g...
# 17  For both app and admin users, an endpoint shou...
# 18  Need to add a test case to services layer to p...
# 20  Observed when Usergrid application servers wer...
# 21  When push notifications are used, Notification...
# 28  Allowing usergrid.api.url.base this field to b...
# 32  During the shard compaction process, columns (...
# 34  Instead of requiring that clients first valida...
# 36  Fixes:\n1. GET entity with text/html was retur...
# 43  Default entity types do not show up on GET /<a...
# 44  In the event an edge exists in graph and the e...
# 51  Concatenating strings when logging creates tem...
# 55  Getting an email when trying to activate an or...
# 61  When I create a new event entity, the API retu...
# 76  We need to be able to attach webhooks at the c...
# 88  1. Add usergrid.api.url.base property (default...
#
#                                        fields.summary
# 7              Improve Duplicate Unique Value Message
# 8   No cursor returned when paging incoming connec...
# 17  Lightweight token validation for users and admins
# 18            Asset files do not appear to be deleted
# 20  Don't log full stack trace on Elasticsearch ti...
# 21              Cache Application queue manager class
# 28  Allow usergrid.api.url.base to be set when cre...
# 32  Enhance shard compaction to track the 'end' of...
# 34  Simplify Central SSO: eliminate ext token vali...
# 36                    Asset and Accept Header changes
# 43  Default entity types do not show up on GET /<a...
# 44  Handle index processing event case where an ed...
# 51  Replace logging string concatenation with form...
# 55  Error occuring when clicking link to activate ...
# 61  POST to /events returns entity that does not e...
# 76                              Admin Action Webhooks
# 88        Org config override for portal and API URLs

# %%
df_out = pd.DataFrame(columns=['context', 'instruction', 'response'])
df_out
# Out:
# Empty DataFrame
# Columns: [context, instruction, response]
# Index: []

# %%
import re

a = '''The Apache HTTP Server (/əˈpætʃi/ ə-PATCH-ee) is a free and open-source cross-platform web server software, released under the terms of Apache License 2.0. It is developed and maintained by a community of developers under the auspices of the Apache Software Foundation.
The vast majority of Apache HTTP Server instances run on a Linux distribution,[5] but current versions also run on Microsoft Windows,[6] OpenVMS,[7] and a wide variety of Unix-like systems. Past versions also ran on NetWare, OS/2 and other operating systems,[8] including ports to mainframes.[9]'''
a = re.sub(r'\[.+?\]', '', a)
a = re.sub(r'\(.+\)', '', a)
a = re.sub(r'[^A-Za-z0-9., ]+', '', a)
print(a)
# Out:
# The Apache HTTP Server  is a free and opensource crossplatform web server software, released under the terms of Apache License 2.0. It is developed and maintained by a community of developers under the auspices of the Apache Software Foundation.The vast majority of Apache HTTP Server instances run on a Linux distribution, but current versions also run on Microsoft Windows, OpenVMS, and a wide variety of Unixlike systems. Past versions also ran on NetWare, OS2 and other operating systems, including ports to mainframes.

# %%
df_out['instruction'] = df['fields.description']
df_out['response'] = df['fields.summary']
df_out['context'] = a
df_out = df_out.dropna()
